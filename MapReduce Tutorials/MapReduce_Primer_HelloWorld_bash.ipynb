# %% [markdown]
# <a href="https://github.com/groda/big_data"><div><img src="https://github.com/groda/big_data/blob/master/logo_bdb.png?raw=true" align=right width="90"></div></a>
#
# # MapReduce: A Primer with <code>Hello World!</code> in bash
# <br>
# <br>
#
# This tutorial serves as a companion to [MapReduce_Primer_HelloWorld.ipynb](https://github.com/groda/big_data/blob/master/MapReduce_Primer_HelloWorld.ipynb), with the implementation carried out in the Bash scripting language requiring only a few lines of code.
#
# For this tutorial, we are going to download the core Hadoop distribution and run Hadoop in _local standalone mode_:
#
# > ❝ _By default, Hadoop is configured to run in a non-distributed mode, as a single Java process._ ❞
#
# (see [https://hadoop.apache.org/docs/stable/.../Standalone_Operation](https://hadoop.apache.org/docs/stable/hadoop-project-dist/hadoop-common/SingleCluster.html#Standalone_Operation))
#
# We are going to run a MapReduce job using MapReduce's [streaming application](https://hadoop.apache.org/docs/stable/hadoop-streaming/HadoopStreaming.html#Hadoop_Streaming). This is not to be confused with real-time streaming:
#
# > ❝ _Hadoop streaming is a utility that comes with the Hadoop distribution. The utility allows you to create and run Map/Reduce jobs with any executable or script as the mapper and/or the reducer._ ❞
#
# MapReduce streaming defaults to using [`IdentityMapper`](https://hadoop.apache.org/docs/stable/api/index.html) and [`IdentityReducer`](https://hadoop.apache.org/docs/stable/api/index.html), thus eliminating the need for explicit specification of a mapper or reducer.
#
# Both input and output are standard files since Hadoop's default filesystem is the regular file system, as specified by the `fs.defaultFS` property in [core-default.xml](https://hadoop.apache.org/docs/stable/hadoop-project-dist/hadoop-common/core-default.xml)).

# %%
# %%bash
# #set -x
# HADOOP_URL="https://dlcdn.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz"
# wget --quiet --no-clobber $HADOOP_URL >/dev/null
# [ ! -d $(basename $HADOOP_URL .tar.gz) ] && tar -xzf $(basename $HADOOP_URL)
# HADOOP_HOME=$(pwd)'/'$(basename $HADOOP_URL .tar.gz)'/bin'
# PATH=$HADOOP_HOME:$PATH
# which java >/dev/null|| apt install -y openjdk-19-jre-headless
# export JAVA_HOME=$(realpath $(which java) | sed 's/\/bin\/java$//')
# echo -e "Hello, World!">hello.txt
# output_dir="output"$(date +"%Y%m%dT%H%M")
# sleep 10
# mapred streaming -input hello.txt -output $output_dir
# ls -lR output*
# cat $output_dir/part-00000
# Out:
# output20240506T1403:
# total 4
# -rw-r--r-- 1 root root 16 May  6 14:04 part-00000
# -rw-r--r-- 1 root root  0 May  6 14:04 _SUCCESS
# 0	Hello, World!
# 2024-05-06 14:04:10,572 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2024-05-06 14:04:10,834 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2024-05-06 14:04:10,834 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2024-05-06 14:04:10,856 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2024-05-06 14:04:11,198 INFO mapred.FileInputFormat: Total input files to process : 1
# 2024-05-06 14:04:11,232 INFO mapreduce.JobSubmitter: number of splits:1
# 2024-05-06 14:04:11,672 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1325117111_0001
# 2024-05-06 14:04:11,676 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2024-05-06 14:04:12,025 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2024-05-06 14:04:12,027 INFO mapreduce.Job: Running job: job_local1325117111_0001
# 2024-05-06 14:04:12,038 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2024-05-06 14:04:12,042 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2024-05-06 14:04:12,054 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-05-06 14:04:12,054 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-05-06 14:04:12,115 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2024-05-06 14:04:12,121 INFO mapred.LocalJobRunner: Starting task: attempt_local1325117111_0001_m_000000_0
# 2024-05-06 14:04:12,157 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-05-06 14:04:12,157 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-05-06 14:04:12,186 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-05-06 14:04:12,197 INFO mapred.MapTask: Processing split: file:/content/hello.txt:0+14
# 2024-05-06 14:04:12,222 INFO mapred.MapTask: numReduceTasks: 1
# 2024-05-06 14:04:12,311 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2024-05-06 14:04:12,311 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2024-05-06 14:04:12,311 INFO mapred.MapTask: soft limit at 83886080
# 2024-05-06 14:04:12,311 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2024-05-06 14:04:12,311 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2024-05-06 14:04:12,317 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2024-05-06 14:04:12,327 INFO mapred.LocalJobRunner:
# 2024-05-06 14:04:12,328 INFO mapred.MapTask: Starting flush of map output
# 2024-05-06 14:04:12,328 INFO mapred.MapTask: Spilling map output
# 2024-05-06 14:04:12,328 INFO mapred.MapTask: bufstart = 0; bufend = 22; bufvoid = 104857600
# 2024-05-06 14:04:12,328 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214396(104857584); length = 1/6553600
# 2024-05-06 14:04:12,338 INFO mapred.MapTask: Finished spill 0
# 2024-05-06 14:04:12,368 INFO mapred.Task: Task:attempt_local1325117111_0001_m_000000_0 is done. And is in the process of committing
# 2024-05-06 14:04:12,373 INFO mapred.LocalJobRunner: file:/content/hello.txt:0+14
# 2024-05-06 14:04:12,373 INFO mapred.Task: Task 'attempt_local1325117111_0001_m_000000_0' done.
# 2024-05-06 14:04:12,383 INFO mapred.Task: Final Counters for attempt_local1325117111_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=141410
# 		FILE: Number of bytes written=779423
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=1
# 		Map output bytes=22
# 		Map output materialized bytes=30
# 		Input split bytes=75
# 		Combine input records=0
# 		Spilled Records=1
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=318767104
# 	File Input Format Counters
# 		Bytes Read=14
# 2024-05-06 14:04:12,384 INFO mapred.LocalJobRunner: Finishing task: attempt_local1325117111_0001_m_000000_0
# 2024-05-06 14:04:12,385 INFO mapred.LocalJobRunner: map task executor complete.
# 2024-05-06 14:04:12,389 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2024-05-06 14:04:12,393 INFO mapred.LocalJobRunner: Starting task: attempt_local1325117111_0001_r_000000_0
# 2024-05-06 14:04:12,404 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2024-05-06 14:04:12,404 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2024-05-06 14:04:12,405 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2024-05-06 14:04:12,412 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@6b4aa0d3
# 2024-05-06 14:04:12,414 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2024-05-06 14:04:12,440 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2382574336, maxSingleShuffleLimit=595643584, mergeThreshold=1572499072, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2024-05-06 14:04:12,451 INFO reduce.EventFetcher: attempt_local1325117111_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2024-05-06 14:04:12,504 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1325117111_0001_m_000000_0 decomp: 26 len: 30 to MEMORY
# 2024-05-06 14:04:12,512 INFO reduce.InMemoryMapOutput: Read 26 bytes from map-output for attempt_local1325117111_0001_m_000000_0
# 2024-05-06 14:04:12,523 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 26, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->26
# 2024-05-06 14:04:12,529 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2024-05-06 14:04:12,531 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2024-05-06 14:04:12,531 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2024-05-06 14:04:12,547 INFO mapred.Merger: Merging 1 sorted segments
# 2024-05-06 14:04:12,548 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 16 bytes
# 2024-05-06 14:04:12,550 INFO reduce.MergeManagerImpl: Merged 1 segments, 26 bytes to disk to satisfy reduce memory limit
# 2024-05-06 14:04:12,551 INFO reduce.MergeManagerImpl: Merging 1 files, 30 bytes from disk
# 2024-05-06 14:04:12,552 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2024-05-06 14:04:12,552 INFO mapred.Merger: Merging 1 sorted segments
# 2024-05-06 14:04:12,558 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 16 bytes
# 2024-05-06 14:04:12,558 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2024-05-06 14:04:12,575 INFO mapred.Task: Task:attempt_local1325117111_0001_r_000000_0 is done. And is in the process of committing
# 2024-05-06 14:04:12,579 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2024-05-06 14:04:12,580 INFO mapred.Task: Task attempt_local1325117111_0001_r_000000_0 is allowed to commit now
# 2024-05-06 14:04:12,582 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1325117111_0001_r_000000_0' to file:/content/output20240506T1403
# 2024-05-06 14:04:12,585 INFO mapred.LocalJobRunner: reduce > reduce
# 2024-05-06 14:04:12,588 INFO mapred.Task: Task 'attempt_local1325117111_0001_r_000000_0' done.
# 2024-05-06 14:04:12,588 INFO mapred.Task: Final Counters for attempt_local1325117111_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=141502
# 		FILE: Number of bytes written=779481
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1
# 		Reduce shuffle bytes=30
# 		Reduce input records=1
# 		Reduce output records=1
# 		Spilled Records=1
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=318767104
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=28
# 2024-05-06 14:04:12,589 INFO mapred.LocalJobRunner: Finishing task: attempt_local1325117111_0001_r_000000_0
# 2024-05-06 14:04:12,589 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2024-05-06 14:04:13,035 INFO mapreduce.Job: Job job_local1325117111_0001 running in uber mode : false
# 2024-05-06 14:04:13,036 INFO mapreduce.Job:  map 100% reduce 100%
# 2024-05-06 14:04:13,038 INFO mapreduce.Job: Job job_local1325117111_0001 completed successfully
# 2024-05-06 14:04:13,056 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=282912
# 		FILE: Number of bytes written=1558904
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=1
# 		Map output bytes=22
# 		Map output materialized bytes=30
# 		Input split bytes=75
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1
# 		Reduce shuffle bytes=30
# 		Reduce input records=1
# 		Reduce output records=1
# 		Spilled Records=2
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=637534208
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=14
# 	File Output Format Counters
# 		Bytes Written=28
# 2024-05-06 14:04:13,056 INFO streaming.StreamJob: Output directory: output20240506T1403
